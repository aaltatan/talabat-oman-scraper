# %%
import pandas as pd
import numpy as np
import json

# %%
def flat_cuisines(lst) -> str:
    if type(lst) is float:
        return lst
    return ", ".join([c['name'] for c in lst])

# %%
def flat_payment_methods(lst) -> str:
    if type(lst) is float:
        return lst
    return ", ".join([c['text'].replace('common:', '').replace('.translation', '') for c in lst])

# %%
with open('sitemap_4.jsonl', 'r', encoding='utf-8') as file:
    data = (json.loads(line[:-1]) for line in file.readlines())

# %%
df = pd.json_normalize(data)

# %%
df['availablePaymentMethods'] = df['availablePaymentMethods'].apply(flat_payment_methods)

# %%
pd.set_option('display.max_columns', 100)

# %%
df['cuisines'] = df['cuisines'].apply(flat_cuisines)

# %%
df = df.drop(['filtersIds'], axis='columns')

# %%
df = df.drop_duplicates()

# %%
# df.to_csv('data.csv')

# %%
len(df['branchId'].unique())
# Out:
# 5921

# %%
to_drop = ['createdAt', 'avgDeliveryTime', 'deliveryTime', 'shopPosition', 'minimumOrderAmount', 'rate', 'totalReviews', 'statusCode', 'totalRatings', 'isTalabatGO', 'deliveryFee', 'status']

# %%
df = df.drop(to_drop, axis='columns')

# %%
df.duplicated().sum()
# Out:
# 81331

# %%
df.columns
# Out:
# Index(['id', 'name', 'cuisineString', 'heroImage', 'logo', 'acceptCreditCard',
#        'acceptDebitCard', 'acceptCash', 'branchName', 'areaName', 'areaId',
#        'branchId', 'restaurantId', 'deliveryAreaId', 'deliverySchedule',
#        'preOrder', 'latitude', 'longitude', 'verticalType', 'isGrocery',
#        'summary', 'branchSlug', 'restaurantSlug', 'branchUrl',
#        'isVatInclusive', 'deliveryChargesType', 'altTalabattxt',
#        'altMunicipaltxt', 'altTouristtxt', 'alternativeDeliveryText',
#        'branchLearnMoreLink', 'IsMigratedToDh', 'isDarkstore', 'shopArea',
#        'shopCity', 'isCokeRestaurant', 'isShopSponcered', 'grlRequired',
#        'cuisines', 'menuUrl', 'view', 'promotionText', 'discountText', 'isNew',
#        'isCateringAvailable', 'contactlessDelivery', 'IsProvideTracking',
#        'isProvideOrderStatus', 'shopType', 'availablePaymentMethods',
#        'Sponsored.category', 'Sponsored.type', 'Sponsored.token'],
#       dtype='object')

# %%
df.query('id == 627920')
# Out:
#            id      name         cuisineString  \
# 2707   627920  Lapaleta  Beverages, Ice cream
# 2846   627920  Lapaleta  Beverages, Ice cream
# 3472   627920  Lapaleta  Beverages, Ice cream
# 14672  627920  Lapaleta  Beverages, Ice cream
# 20274  627920  Lapaleta  Beverages, Ice cream
# 20279  627920  Lapaleta  Beverages, Ice cream
# 23352  627920  Lapaleta  Beverages, Ice cream
# 25061  627920  Lapaleta  Beverages, Ice cream
# 34348  627920  Lapaleta  Beverages, Ice cream
# 36927  627920  Lapaleta  Beverages, Ice cream
# 44572  627920  Lapaleta  Beverages, Ice cream
# 44698  627920  Lapaleta  Beverages, Ice cream
# 47329  627920  Lapaleta  Beverages, Ice cream
# 51244  627920  Lapaleta  Beverages, Ice cream
# 55555  627920  Lapaleta  Beverages, Ice cream
# 63300  627920  Lapaleta  Beverages, Ice cream
# 63323  627920  Lapaleta  Beverages, Ice cream
# 66072  627920  Lapaleta  Beverages, Ice cream
# 71464  627920  Lapaleta  Beverages, Ice cream
# 74901  627920  Lapaleta  Beverages, Ice cream
# 76057  627920  Lapaleta  Beverages, Ice cream
# 78920  627920  Lapaleta  Beverages, Ice cream
#
#                                                heroImage  \
# 2707   https://images.deliveryhero.io/image/talabat/r...
# 2846   https://images.deliveryhero.io/image/talabat/r...
# 3472   https://images.deliveryhero.io/image/talabat/r...
# 14672  https://images.deliveryhero.io/image/talabat/r...
# 20274  https://images.deliveryhero.io/image/talabat/r...
# 20279  https://images.deliveryhero.io/image/talabat/r...
# 23352  https://images.deliveryhero.io/image/talabat/r...
# 25061  https://images.deliveryhero.io/image/talabat/r...
# 34348  https://images.deliveryhero.io/image/talabat/r...
# 36927  https://images.deliveryhero.io/image/talabat/r...
# 44572  https://images.deliveryhero.io/image/talabat/r...
# 44698  https://images.deliveryhero.io/image/talabat/r...
# 47329  https://images.deliveryhero.io/image/talabat/r...
# 51244  https://images.deliveryhero.io/image/talabat/r...
# 55555  https://images.deliveryhero.io/image/talabat/r...
# 63300  https://images.deliveryhero.io/image/talabat/r...
# 63323  https://images.deliveryhero.io/image/talabat/r...
# 66072  https://images.deliveryhero.io/image/talabat/r...
# 71464  https://images.deliveryhero.io/image/talabat/r...
# 74901  https://images.deliveryhero.io/image/talabat/r...
# 76057  https://images.deliveryhero.io/image/talabat/r...
# 78920  https://images.deliveryhero.io/image/talabat/r...
#
#                                                     logo  acceptCreditCard  \
# 2707   https://images.deliveryhero.io/image/talabat/r...              True
# 2846   https://images.deliveryhero.io/image/talabat/r...              True
# 3472   https://images.deliveryhero.io/image/talabat/r...              True
# 14672  https://images.deliveryhero.io/image/talabat/r...              True
# 20274  https://images.deliveryhero.io/image/talabat/r...              True
# 20279  https://images.deliveryhero.io/image/talabat/r...              True
# 23352  https://images.deliveryhero.io/image/talabat/r...              True
# 25061  https://images.deliveryhero.io/image/talabat/r...              True
# 34348  https://images.deliveryhero.io/image/talabat/r...              True
# 36927  https://images.deliveryhero.io/image/talabat/r...              True
# 44572  https://images.deliveryhero.io/image/talabat/r...              True
# 44698  https://images.deliveryhero.io/image/talabat/r...              True
# 47329  https://images.deliveryhero.io/image/talabat/r...              True
# 51244  https://images.deliveryhero.io/image/talabat/r...              True
# 55555  https://images.deliveryhero.io/image/talabat/r...              True
# 63300  https://images.deliveryhero.io/image/talabat/r...              True
# 63323  https://images.deliveryhero.io/image/talabat/r...              True
# 66072  https://images.deliveryhero.io/image/talabat/r...              True
# 71464  https://images.deliveryhero.io/image/talabat/r...              True
# 74901  https://images.deliveryhero.io/image/talabat/r...              True
# 76057  https://images.deliveryhero.io/image/talabat/r...              True
# 78920  https://images.deliveryhero.io/image/talabat/r...              True
#
#        acceptDebitCard  acceptCash        branchName areaName areaId  \
# 2707             False        True  LAPALETA, Sallan            None
# 2846             False        True  LAPALETA, Sallan            None
# 3472             False        True  LAPALETA, Sallan            None
# 14672            False        True  LAPALETA, Sallan            None
# 20274            False        True  LAPALETA, Sallan            None
# 20279            False        True  LAPALETA, Sallan            None
# 23352            False        True  LAPALETA, Sallan            None
# 25061            False        True  LAPALETA, Sallan            None
# 34348            False        True  LAPALETA, Sallan            None
# 36927            False        True  LAPALETA, Sallan            None
# 44572            False        True  LAPALETA, Sallan            None
# 44698            False        True  LAPALETA, Sallan            None
# 47329            False        True  LAPALETA, Sallan            None
# 51244            False        True  LAPALETA, Sallan            None
# 55555            False        True  LAPALETA, Sallan            None
# 63300            False        True  LAPALETA, Sallan            None
# 63323            False        True  LAPALETA, Sallan            None
# 66072            False        True  LAPALETA, Sallan            None
# 71464            False        True  LAPALETA, Sallan            None
# 74901            False        True  LAPALETA, Sallan            None
# 76057            False        True  LAPALETA, Sallan            None
# 78920            False        True  LAPALETA, Sallan            None
#
#        branchId  restaurantId deliveryAreaId deliverySchedule  preOrder  \
# 2707     644418        627920           None             Open      True
# 2846     644418        627920           None             Open      True
# 3472     644418        627920           None             Open      True
# 14672    644418        627920           None             Open      True
# 20274    644418        627920           None             Open      True
# 20279    644418        627920           None             Open      True
# 23352    644418        627920           None             Open      True
# 25061    644418        627920           None             Open      True
# 34348    644418        627920           None             Open      True
# 36927    644418        627920           None             Open      True
# 44572    644418        627920           None             Open      True
# 44698    644418        627920           None             Open      True
# 47329    644418        627920           None             Open      True
# 51244    644418        627920           None             Open      True
# 55555    644418        627920           None             Open      True
# 63300    644418        627920           None             Open      True
# 63323    644418        627920           None             Open      True
# 66072    644418        627920           None             Open      True
# 71464    644418        627920           None             Open      True
# 74901    644418        627920           None             Open      True
# 76057    644418        627920           None             Open      True
# 78920    644418        627920           None             Open      True
#
#          latitude   longitude  verticalType  isGrocery summary  \
# 2707   24.4001363  56.7223019             0      False
# 2846   24.4001363  56.7223019             0      False
# 3472   24.4001363  56.7223019             0      False
# 14672  24.4001363  56.7223019             0      False
# 20274  24.4001363  56.7223019             0      False
# 20279  24.4001363  56.7223019             0      False
# 23352  24.4001363  56.7223019             0      False
# 25061  24.4001363  56.7223019             0      False
# 34348  24.4001363  56.7223019             0      False
# 36927  24.4001363  56.7223019             0      False
# 44572  24.4001363  56.7223019             0      False
# 44698  24.4001363  56.7223019             0      False
# 47329  24.4001363  56.7223019             0      False
# 51244  24.4001363  56.7223019             0      False
# 55555  24.4001363  56.7223019             0      False
# 63300  24.4001363  56.7223019             0      False
# 63323  24.4001363  56.7223019             0      False
# 66072  24.4001363  56.7223019             0      False
# 71464  24.4001363  56.7223019             0      False
# 74901  24.4001363  56.7223019             0      False
# 76057  24.4001363  56.7223019             0      False
# 78920  24.4001363  56.7223019             0      False
#
#             branchSlug restaurantSlug       branchUrl  isVatInclusive  \
# 2707   lapaleta-sallan       lapaleta  /oman/lapaleta           False
# 2846   lapaleta-sallan       lapaleta  /oman/lapaleta           False
# 3472   lapaleta-sallan       lapaleta  /oman/lapaleta           False
# 14672  lapaleta-sallan       lapaleta  /oman/lapaleta           False
# 20274  lapaleta-sallan       lapaleta  /oman/lapaleta           False
# 20279  lapaleta-sallan       lapaleta  /oman/lapaleta           False
# 23352  lapaleta-sallan       lapaleta  /oman/lapaleta           False
# 25061  lapaleta-sallan       lapaleta  /oman/lapaleta           False
# 34348  lapaleta-sallan       lapaleta  /oman/lapaleta           False
# 36927  lapaleta-sallan       lapaleta  /oman/lapaleta           False
# 44572  lapaleta-sallan       lapaleta  /oman/lapaleta           False
# 44698  lapaleta-sallan       lapaleta  /oman/lapaleta           False
# 47329  lapaleta-sallan       lapaleta  /oman/lapaleta           False
# 51244  lapaleta-sallan       lapaleta  /oman/lapaleta           False
# 55555  lapaleta-sallan       lapaleta  /oman/lapaleta           False
# 63300  lapaleta-sallan       lapaleta  /oman/lapaleta           False
# 63323  lapaleta-sallan       lapaleta  /oman/lapaleta           False
# 66072  lapaleta-sallan       lapaleta  /oman/lapaleta           False
# 71464  lapaleta-sallan       lapaleta  /oman/lapaleta           False
# 74901  lapaleta-sallan       lapaleta  /oman/lapaleta           False
# 76057  lapaleta-sallan       lapaleta  /oman/lapaleta           False
# 78920  lapaleta-sallan       lapaleta  /oman/lapaleta           False
#
#        deliveryChargesType altTalabattxt altMunicipaltxt altTouristtxt  \
# 2707                     0
# 2846                     0
# 3472                     0
# 14672                    0
# 20274                    0
# 20279                    0
# 23352                    0
# 25061                    0
# 34348                    0
# 36927                    0
# 44572                    0
# 44698                    0
# 47329                    0
# 51244                    0
# 55555                    0
# 63300                    0
# 63323                    0
# 66072                    0
# 71464                    0
# 74901                    0
# 76057                    0
# 78920                    0
#
#       alternativeDeliveryText branchLearnMoreLink  IsMigratedToDh  \
# 2707                                                        False
# 2846                                                        False
# 3472                                                        False
# 14672                                                       False
# 20274                                                       False
# 20279                                                       False
# 23352                                                       False
# 25061                                                       False
# 34348                                                       False
# 36927                                                       False
# 44572                                                       False
# 44698                                                       False
# 47329                                                       False
# 51244                                                       False
# 55555                                                       False
# 63300                                                       False
# 63323                                                       False
# 66072                                                       False
# 71464                                                       False
# 74901                                                       False
# 76057                                                       False
# 78920                                                       False
#
#        isDarkstore  shopArea  shopCity  isCokeRestaurant  isShopSponcered  \
# 2707         False      2611        68             False            False
# 2846         False      2611        68             False            False
# 3472         False      2611        68             False            False
# 14672        False      2611        68             False            False
# 20274        False      2611        68             False            False
# 20279        False      2611        68             False            False
# 23352        False      2611        68             False            False
# 25061        False      2611        68             False            False
# 34348        False      2611        68             False            False
# 36927        False      2611        68             False            False
# 44572        False      2611        68             False            False
# 44698        False      2611        68             False            False
# 47329        False      2611        68             False            False
# 51244        False      2611        68             False            False
# 55555        False      2611        68             False            False
# 63300        False      2611        68             False            False
# 63323        False      2611        68             False            False
# 66072        False      2611        68             False            False
# 71464        False      2611        68             False            False
# 74901        False      2611        68             False            False
# 76057        False      2611        68             False            False
# 78920        False      2611        68             False            False
#
#        grlRequired              cuisines  \
# 2707         False  Beverages, Ice cream
# 2846         False  Beverages, Ice cream
# 3472         False  Beverages, Ice cream
# 14672        False  Beverages, Ice cream
# 20274        False  Beverages, Ice cream
# 20279        False  Beverages, Ice cream
# 23352        False  Beverages, Ice cream
# 25061        False  Beverages, Ice cream
# 34348        False  Beverages, Ice cream
# 36927        False  Beverages, Ice cream
# 44572        False  Beverages, Ice cream
# 44698        False  Beverages, Ice cream
# 47329        False  Beverages, Ice cream
# 51244        False  Beverages, Ice cream
# 55555        False  Beverages, Ice cream
# 63300        False  Beverages, Ice cream
# 63323        False  Beverages, Ice cream
# 66072        False  Beverages, Ice cream
# 71464        False  Beverages, Ice cream
# 74901        False  Beverages, Ice cream
# 76057        False  Beverages, Ice cream
# 78920        False  Beverages, Ice cream
#
#                                        menuUrl  view promotionText  \
# 2707   /oman/restaurant/644418/lapaleta-sallan     0
# 2846   /oman/restaurant/644418/lapaleta-sallan     0
# 3472   /oman/restaurant/644418/lapaleta-sallan     0
# 14672  /oman/restaurant/644418/lapaleta-sallan     0
# 20274  /oman/restaurant/644418/lapaleta-sallan     0
# 20279  /oman/restaurant/644418/lapaleta-sallan     0
# 23352  /oman/restaurant/644418/lapaleta-sallan     0
# 25061  /oman/restaurant/644418/lapaleta-sallan     0
# 34348  /oman/restaurant/644418/lapaleta-sallan     0
# 36927  /oman/restaurant/644418/lapaleta-sallan     0
# 44572  /oman/restaurant/644418/lapaleta-sallan     0
# 44698  /oman/restaurant/644418/lapaleta-sallan     0
# 47329  /oman/restaurant/644418/lapaleta-sallan     0
# 51244  /oman/restaurant/644418/lapaleta-sallan     0
# 55555  /oman/restaurant/644418/lapaleta-sallan     0
# 63300  /oman/restaurant/644418/lapaleta-sallan     0
# 63323  /oman/restaurant/644418/lapaleta-sallan     0
# 66072  /oman/restaurant/644418/lapaleta-sallan     0
# 71464  /oman/restaurant/644418/lapaleta-sallan     0
# 74901  /oman/restaurant/644418/lapaleta-sallan     0
# 76057  /oman/restaurant/644418/lapaleta-sallan     0
# 78920  /oman/restaurant/644418/lapaleta-sallan     0
#
#       discountText  isNew  isCateringAvailable  contactlessDelivery  \
# 2707                False                False                 True
# 2846                False                False                 True
# 3472                False                False                 True
# 14672               False                False                 True
# 20274               False                False                 True
# 20279               False                False                 True
# 23352               False                False                 True
# 25061               False                False                 True
# 34348               False                False                 True
# 36927               False                False                 True
# 44572               False                False                 True
# 44698               False                False                 True
# 47329               False                False                 True
# 51244               False                False                 True
# 55555               False                False                 True
# 63300               False                False                 True
# 63323               False                False                 True
# 66072               False                False                 True
# 71464               False                False                 True
# 74901               False                False                 True
# 76057               False                False                 True
# 78920               False                False                 True
#
#        IsProvideTracking  isProvideOrderStatus shopType  \
# 2707                True                 False      TGO
# 2846                True                 False      TGO
# 3472                True                 False      TGO
# 14672               True                 False      TGO
# 20274               True                 False      TGO
# 20279               True                 False      TGO
# 23352               True                 False      TGO
# 25061               True                 False      TGO
# 34348               True                 False      TGO
# 36927               True                 False      TGO
# 44572               True                 False      TGO
# 44698               True                 False      TGO
# 47329               True                 False      TGO
# 51244               True                 False      TGO
# 55555               True                 False      TGO
# 63300               True                 False      TGO
# 63323               True                 False      TGO
# 66072               True                 False      TGO
# 71464               True                 False      TGO
# 74901               True                 False      TGO
# 76057               True                 False      TGO
# 78920               True                 False      TGO
#
#       availablePaymentMethods Sponsored.category Sponsored.type  \
# 2707   visa, mastercard, cash
# 2846   visa, mastercard, cash
# 3472   visa, mastercard, cash
# 14672  visa, mastercard, cash
# 20274  visa, mastercard, cash
# 20279  visa, mastercard, cash
# 23352  visa, mastercard, cash
# 25061  visa, mastercard, cash
# 34348  visa, mastercard, cash
# 36927  visa, mastercard, cash
# 44572  visa, mastercard, cash
# 44698  visa, mastercard, cash
# 47329  visa, mastercard, cash
# 51244  visa, mastercard, cash
# 55555  visa, mastercard, cash
# 63300  visa, mastercard, cash
# 63323  visa, mastercard, cash
# 66072  visa, mastercard, cash
# 71464  visa, mastercard, cash
# 74901  visa, mastercard, cash
# 76057  visa, mastercard, cash
# 78920  visa, mastercard, cash
#
#       Sponsored.token
# 2707
# 2846
# 3472
# 14672
# 20274
# 20279
# 23352
# 25061
# 34348
# 36927
# 44572
# 44698
# 47329
# 51244
# 55555
# 63300
# 63323
# 66072
# 71464
# 74901
# 76057
# 78920

# %%
df = df.drop_duplicates()

# %%
df.sort_values('branchId').to_excel('data_final.xlsx')
